# %% [markdown]
# # Kike Sharks CSV clean

# %%
import pandas as pd
import numpy as np
import warnings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('attacks.csv', encoding='latin1')

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df = df.T

# %%
nan_cols = df.isnull().sum()

# %%
nan_cols[nan_cols>8]
# Out:
# 1366      9
# 1569      9
# 1848      9
# 2196      9
# 3033      9
# 3378      9
# 3938      9
# 4018      9
# 4680      9
# 4976     10
# 5029      9
# 5036     10
# 5246      9
# 5356      9
# 5729      9
# 5812      9
# 5846      9
# 5850      9
# 5880      9
# 5895      9
# 5965      9
# 6044      9
# 6080     10
# 6081      9
# 6108     10
# 6122     10
# 6125      9
# 6130     10
# 6133      9
# 6158      9
# 6165     10
# 6171      9
# 6199      9
# 6302     22
# 6303     22
# 6304     22
# 6305     22
# 6306     22
# 6307     22
# 6308     22
# 6309     23
# 6310     23
# 6311     23
# 6312     23
# 6313     23
# 6314     23
# 6315     23
# 6316     23
# 6317     23
# 6318     23
# 6319     23
# 6320     23
# 6321     23
# 6322     23
# 6323     23
# 6324     23
# 6325     23
# 6326     23
# 6327     23
# 6328     23
# 6329     23
# 6330     23
# 6331     23
# 6332     23
# 6333     23
# 6334     23
# 6335     23
# 6336     23
# 6337     23
# 6338     23
# 6339     23
# ...

# %%
df = df.drop(columns=nan_cols[nan_cols>8].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, Case Number to Unnamed: 23
# Columns: 6269 entries, 0 to 6301
# dtypes: object(6269)
# memory usage: 1.1+ MB

# %%
df = df.T

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6269 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6268 non-null   object
#  1   Date                    6269 non-null   object
#  2   Year                    6267 non-null   object
#  3   Type                    6265 non-null   object
#  4   Country                 6225 non-null   object
#  5   Area                    5841 non-null   object
#  6   Location                5757 non-null   object
#  7   Activity                5748 non-null   object
#  8   Name                    6079 non-null   object
#  9   Sex                     5729 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6246 non-null   object
#  12  Fatal (Y/N)             5743 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
# ### Limpiar columnas una por una.

# %%
df = df.dropna(axis = 0, subset=['Country'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6225 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6224 non-null   object
#  1   Date                    6225 non-null   object
#  2   Year                    6223 non-null   object
#  3   Type                    6221 non-null   object
#  4   Country                 6225 non-null   object
#  5   Area                    5827 non-null   object
#  6   Location                5746 non-null   object
#  7   Activity                5708 non-null   object
#  8   Name                    6038 non-null   object
#  9   Sex                     5687 non-null   object
#  10  Age                     3462 non-null   object
#  11  Injury                  6202 non-null   object
#  12  Fatal (Y/N)             5704 non-null   object
#  13  Time                    2941 non-null   object
# ...

# %%
df = df.dropna(axis = 0, subset=['Area'])

# %%
df = df.dropna(axis = 0, subset=['Location'])

# %%
df = df.dropna(axis = 0, subset=['Activity'])

# %%
columnas = df.columns
columnas
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
cols = []
for col in columnas:
    col = col.replace(' ', '_').lower()
    cols.append(col)
cols
# Out:
# ['case_number',
#  'date',
#  'year',
#  'type',
#  'country',
#  'area',
#  'location',
#  'activity',
#  'name',
#  'sex_',
#  'age',
#  'injury',
#  'fatal_(y/n)',
#  'time',
#  'species_',
#  'investigator_or_source',
#  'pdf',
#  'href_formula',
#  'href',
#  'case_number.1',
#  'case_number.2',
#  'original_order',
#  'unnamed:_22',
#  'unnamed:_23']

# %%
df.columns = cols

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5112 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             5111 non-null   object
#  1   date                    5112 non-null   object
#  2   year                    5111 non-null   object
#  3   type                    5110 non-null   object
#  4   country                 5112 non-null   object
#  5   area                    5112 non-null   object
#  6   location                5112 non-null   object
#  7   activity                5112 non-null   object
#  8   name                    5014 non-null   object
#  9   sex_                    4773 non-null   object
#  10  age                     3145 non-null   object
#  11  injury                  5102 non-null   object
#  12  fatal_(y/n)             4752 non-null   object
#  13  time                    2778 non-null   object
# ...

# %%
df=df.rename(columns={'sex_': 'sex'})

# %%
df=df.rename(columns={'fatal_(y/n)': 'fatal'})

# %%
df=df.rename(columns={'species_': 'species'})

# %%
df=df.rename(columns={'unnamed:_23': 'extra_info'})

# %%
df=df.rename(columns={'unnamed:_22': 'observations'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5112 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             5111 non-null   object
#  1   date                    5112 non-null   object
#  2   year                    5111 non-null   object
#  3   type                    5110 non-null   object
#  4   country                 5112 non-null   object
#  5   area                    5112 non-null   object
#  6   location                5112 non-null   object
#  7   activity                5112 non-null   object
#  8   name                    5014 non-null   object
#  9   sex                     4773 non-null   object
#  10  age                     3145 non-null   object
#  11  injury                  5102 non-null   object
#  12  fatal                   4752 non-null   object
#  13  time                    2778 non-null   object
# ...

# %%
df = df.dropna(axis = 0, subset=['fatal'])

# %%
df = df.dropna(axis = 0, subset=['investigator_or_source'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4743 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             4742 non-null   object
#  1   date                    4743 non-null   object
#  2   year                    4742 non-null   object
#  3   type                    4742 non-null   object
#  4   country                 4743 non-null   object
#  5   area                    4743 non-null   object
#  6   location                4743 non-null   object
#  7   activity                4743 non-null   object
#  8   name                    4664 non-null   object
#  9   sex                     4438 non-null   object
#  10  age                     2961 non-null   object
#  11  injury                  4737 non-null   object
#  12  fatal                   4743 non-null   object
#  13  time                    2647 non-null   object
# ...

# %%
df = df.dropna(axis = 0, subset=['time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2647 entries, 0 to 6265
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             2647 non-null   object
#  1   date                    2647 non-null   object
#  2   year                    2647 non-null   object
#  3   type                    2646 non-null   object
#  4   country                 2647 non-null   object
#  5   area                    2647 non-null   object
#  6   location                2647 non-null   object
#  7   activity                2647 non-null   object
#  8   name                    2635 non-null   object
#  9   sex                     2567 non-null   object
#  10  age                     2158 non-null   object
#  11  injury                  2645 non-null   object
#  12  fatal                   2647 non-null   object
#  13  time                    2647 non-null   object
# ...

# %%
df = df.dropna(axis = 0, subset=['sex'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2567 entries, 0 to 6265
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             2567 non-null   object
#  1   date                    2567 non-null   object
#  2   year                    2567 non-null   object
#  3   type                    2566 non-null   object
#  4   country                 2567 non-null   object
#  5   area                    2567 non-null   object
#  6   location                2567 non-null   object
#  7   activity                2567 non-null   object
#  8   name                    2560 non-null   object
#  9   sex                     2567 non-null   object
#  10  age                     2146 non-null   object
#  11  injury                  2566 non-null   object
#  12  fatal                   2567 non-null   object
#  13  time                    2567 non-null   object
# ...

# %%
df = df.dropna(axis = 0, subset=['species'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 6265
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1649 non-null   object
#  1   date                    1649 non-null   object
#  2   year                    1649 non-null   object
#  3   type                    1649 non-null   object
#  4   country                 1649 non-null   object
#  5   area                    1649 non-null   object
#  6   location                1649 non-null   object
#  7   activity                1649 non-null   object
#  8   name                    1647 non-null   object
#  9   sex                     1649 non-null   object
#  10  age                     1423 non-null   object
#  11  injury                  1649 non-null   object
#  12  fatal                   1649 non-null   object
#  13  time                    1649 non-null   object
# ...

# %%
df['observations']= 'None'

# %%
df['extra_info']='None'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 6265
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1649 non-null   object
#  1   date                    1649 non-null   object
#  2   year                    1649 non-null   object
#  3   type                    1649 non-null   object
#  4   country                 1649 non-null   object
#  5   area                    1649 non-null   object
#  6   location                1649 non-null   object
#  7   activity                1649 non-null   object
#  8   name                    1647 non-null   object
#  9   sex                     1649 non-null   object
#  10  age                     1423 non-null   object
#  11  injury                  1649 non-null   object
#  12  fatal                   1649 non-null   object
#  13  time                    1649 non-null   object
# ...

# %%
df.name = df.name.fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 6265
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1649 non-null   object
#  1   date                    1649 non-null   object
#  2   year                    1649 non-null   object
#  3   type                    1649 non-null   object
#  4   country                 1649 non-null   object
#  5   area                    1649 non-null   object
#  6   location                1649 non-null   object
#  7   activity                1649 non-null   object
#  8   name                    1649 non-null   object
#  9   sex                     1649 non-null   object
#  10  age                     1423 non-null   object
#  11  injury                  1649 non-null   object
#  12  fatal                   1649 non-null   object
#  13  time                    1649 non-null   object
# ...

# %%
df.age.unique()
# Out:
# array(['57', '18', '15', '32', '21', nan, '30', '60', '33', '19', '25',
#        '10', '69', '55', '35', '20', '54', '22', '31', '40', '37', '13',
#        '34', '50', '46', '48', '17', '28', '65', '73', '58', '36', '60s',
#        '51', '61', '59', '42', '6', '23', '29', '39', '24', '12', '26',
#        '11', '71', '43', '44', '14', '27', '62', '52', '38', '68', '16',
#        '47', '63', '70', '9', '41', '40s', '53', '20s', '7', '66', '45',
#        '74', '64', '8', '56', '49', '18 or 20', 'Teen', '30s', '77', '84',
#        '\xa0 ', ' ', '30 or 36', '6½', '5', ' 30', ' 28', "60's", '>50',
#        '30 & 32', '13 or 18', '7 or 8', '9 or 10', '13 or 14'],
#       dtype=object)

# %%
df.age=df.age.str.replace('60s', '60')

# %%
df.age=df.age.str.replace('20s', '20')

# %%
df.age=df.age.str.replace('40s', '40')

# %%
df.age=df.age.str.replace('18 or 20', '19')

# %%
df.age=df.age.str.replace('Teen', '10')

# %%
df.age=df.age.str.replace('30s', '30')

# %%
df.age=df.age.str.replace('\xa0', 'nan')

# %%
df.age=df.age.str.replace(', ', 'nan')

# %%
df.age=df.age.str.replace('30 or 36', '33')

# %%
df.age=df.age.str.replace('6½', '6')

# %%
df.age=df.age.str.replace("60's", '60')

# %%
df.age=df.age.str.replace('>50', '49')

# %%
df.age=df.age.str.replace('30 & 32', '31')

# %%
df.age=df.age.str.replace('13 or 18', '15')

# %%
df.age=df.age.str.replace('7 or 8', '8')

# %%
df.age=df.age.str.replace('9 or 10', '9')

# %%
df.age=df.age.str.replace('13 or 14', '14')

# %%
df.age.unique()
# Out:
# array(['57', '18', '15', '32', '21', nan, '30', '60', '33', '19', '25',
#        '10', '69', '55', '35', '20', '54', '22', '31', '40', '37', '13',
#        '34', '50', '46', '48', '17', '28', '65', '73', '58', '36', '51',
#        '61', '59', '42', '6', '23', '29', '39', '24', '12', '26', '11',
#        '71', '43', '44', '14', '27', '62', '52', '38', '68', '16', '47',
#        '63', '70', '9', '41', '53', '7', '66', '45', '74', '64', '8',
#        '56', '49', '77', '84', 'nan ', ' ', '5', ' 30', ' 28'],
#       dtype=object)

# %%
df.age=df.age.str.replace(', ', 'nan')

# %%
df.age=df.age.str.replace(' ', 'nan')

# %%
df.age.unique()
# Out:
# array(['57', '18', '15', '32', '21', nan, '30', '60', '33', '19', '25',
#        '10', '69', '55', '35', '20', '54', '22', '31', '40', '37', '13',
#        '34', '50', '46', '48', '17', '28', '65', '73', '58', '36', '51',
#        '61', '59', '42', '6', '23', '29', '39', '24', '12', '26', '11',
#        '71', '43', '44', '14', '27', '62', '52', '38', '68', '16', '47',
#        '63', '70', '9', '41', '53', '7', '66', '45', '74', '64', '8',
#        '56', '49', '77', '84', 'nannan', 'nan', '5', 'nan30', 'nan28'],
#       dtype=object)

# %%
df.age=df.age.str.replace('nan30', '30')

# %%
df.age=df.age.str.replace('nan28', '28')

# %%
df.age=df.age.str.replace('nannan', 'nan')

# %%
df.age.unique()
# Out:
# array(['57', '18', '15', '32', '21', nan, '30', '60', '33', '19', '25',
#        '10', '69', '55', '35', '20', '54', '22', '31', '40', '37', '13',
#        '34', '50', '46', '48', '17', '28', '65', '73', '58', '36', '51',
#        '61', '59', '42', '6', '23', '29', '39', '24', '12', '26', '11',
#        '71', '43', '44', '14', '27', '62', '52', '38', '68', '16', '47',
#        '63', '70', '9', '41', '53', '7', '66', '45', '74', '64', '8',
#        '56', '49', '77', '84', 'nan', '5'], dtype=object)

# %%
df.age=df.age.str.replace('np.', '')

# %%
df.age.unique()
# Out:
# array(['57', '18', '15', '32', '21', nan, '30', '60', '33', '19', '25',
#        '10', '69', '55', '35', '20', '54', '22', '31', '40', '37', '13',
#        '34', '50', '46', '48', '17', '28', '65', '73', '58', '36', '51',
#        '61', '59', '42', '6', '23', '29', '39', '24', '12', '26', '11',
#        '71', '43', '44', '14', '27', '62', '52', '38', '68', '16', '47',
#        '63', '70', '9', '41', '53', '7', '66', '45', '74', '64', '8',
#        '56', '49', '77', '84', 'nan', '5'], dtype=object)

# %%
df.age = df.age.fillna('')

# %%
df.age.unique()
# Out:
# array(['57', '18', '15', '32', '21', nan, '30', '60', '33', '19', '25',
#        '10', '69', '55', '35', '20', '54', '22', '31', '40', '37', '13',
#        '34', '50', '46', '48', '17', '28', '65', '73', '58', '36', '51',
#        '61', '59', '42', '6', '23', '29', '39', '24', '12', '26', '11',
#        '71', '43', '44', '14', '27', '62', '52', '38', '68', '16', '47',
#        '63', '70', '9', '41', '53', '7', '66', '45', '74', '64', '8',
#        '56', '49', '77', '84', 'nan', '5'], dtype=object)

# %%
df.age = df.age.astype('int32', errors='ignore')

# %%
df.age
# Out:
# 0        57
# 6        18
# 8        15
# 10       32
# 13       21
# 16
# 18       30
# 20
# 21       60
# 22
# 23       32
# 24       33
# 30
# 34       19
# 35       25
# 36       10
# 37       69
# 38       18
# 40       55
# 42       35
# 43
# 49
# 51       20
# 53       54
# 60       25
# 63       25
# 64       22
# 66       31
# 71       15
# 72
# 73
# 74       54
# 75       40
# 77
# 78
# 80
# 87       18
# 89       35
# 96       37
# 100      69
# 102      13
# 104      34
# 105
# 113
# 116      40
# 117      50
# 118
# 120
# 121      46
# 123      13
# 133      48
# 134
# 138      32
# 140
# 155      17
# 156      28
# 166      17
# 169
# 172
# 177
# 183      55
# 186      48
# 191
# 192      55
# 196      20
# 197      65
# 198      73
# 199      58
# 203      36
# 211      17
# 219      60
# 220      51
# 227      25
# 232      21
# 234      40
# 242      31
# 246      61
# 251      59
# 254      34
# 259      42
# 261
# 263       6
# 264      19
# 267      60
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 6265
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1649 non-null   object
#  1   date                    1649 non-null   object
#  2   year                    1649 non-null   object
#  3   type                    1649 non-null   object
#  4   country                 1649 non-null   object
#  5   area                    1649 non-null   object
#  6   location                1649 non-null   object
#  7   activity                1649 non-null   object
#  8   name                    1649 non-null   object
#  9   sex                     1649 non-null   object
#  10  age                     1649 non-null   object
#  11  injury                  1649 non-null   object
#  12  fatal                   1649 non-null   object
#  13  time                    1649 non-null   object
# ...

# %%
df.to_csv('sharks_clean_v1', index=False)

# %%
df = pd.read_csv('sharks_clean_v1', na_values=[' '])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1649 non-null   object
#  1   date                    1649 non-null   object
#  2   year                    1649 non-null   float64
#  3   type                    1649 non-null   object
#  4   country                 1649 non-null   object
#  5   area                    1649 non-null   object
#  6   location                1649 non-null   object
#  7   activity                1649 non-null   object
#  8   name                    1649 non-null   object
#  9   sex                     1649 non-null   object
#  10  age                     1421 non-null   float64
#  11  injury                  1649 non-null   object
#  12  fatal                   1649 non-null   object
#  13  time                    1647 non-null   object
# ...

# %%
df.year.unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 1998., 1997., 1996., 1995., 1994., 1993., 1992.,
#        1991., 1990., 1989., 1988., 1987., 1986., 1985., 1984., 1983.,
#        1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975., 1974.,
#        1973., 1972., 1971., 1970., 1969., 1968., 1967., 1966., 1965.,
#        1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957., 1956.,
#        1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948., 1947.,
#        1946., 1945., 1944., 1943., 1942., 1941., 1940., 1939., 1938.,
#        1937., 1936., 1935., 1934., 1932., 1931., 1930., 1929., 1928.,
#        1927., 1926., 1925., 1924., 1922., 1921., 1919., 1918., 1916.,
#        1914., 1912., 1910., 1906., 1905., 1901., 1897., 1896., 1894.,
#        1892., 1889., 1888., 1880., 1878., 1877., 1874., 1871., 1868.,
#        1862., 1852.,    0.])

# %%
df.year.value_counts()
# Out:
# 2015.0    68
# 2007.0    59
# 2012.0    59
# 2013.0    56
# 2002.0    54
# 2009.0    47
# 2004.0    47
# 2003.0    45
# 2005.0    44
# 2010.0    42
# 2006.0    42
# 2014.0    42
# 2016.0    41
# 2008.0    41
# 2017.0    39
# 2011.0    38
# 2000.0    36
# 2001.0    30
# 1961.0    29
# 1992.0    27
# 1999.0    27
# 1963.0    26
# 1962.0    25
# 1995.0    23
# 2018.0    23
# 1998.0    23
# 1991.0    22
# 1996.0    22
# 1993.0    21
# 1997.0    20
# 1960.0    19
# 1958.0    18
# 1966.0    18
# 1959.0    18
# 1989.0    18
# 1994.0    17
# 1990.0    16
# 1983.0    16
# 1981.0    16
# 1964.0    15
# 1986.0    15
# 1984.0    15
# 1988.0    14
# 1975.0    13
# 1982.0    12
# 1987.0    12
# 1980.0    12
# 1985.0    12
# 1974.0    11
# 1967.0    11
# 1976.0     9
# 1971.0     9
# 1965.0     9
# 1972.0     8
# 1969.0     8
# 1950.0     8
# 1957.0     8
# 1968.0     8
# 1942.0     6
# 1922.0     6
# 1977.0     6
# 1934.0     6
# 1978.0     5
# 1947.0     5
# 1956.0     5
# 1951.0     5
# ...

# %%
df.age
# Out:
# 0       57.0
# 1       18.0
# 2       15.0
# 3       32.0
# 4       21.0
# 5        NaN
# 6       30.0
# 7        NaN
# 8       60.0
# 9        NaN
# 10      32.0
# 11      33.0
# 12       NaN
# 13      19.0
# 14      25.0
# 15      10.0
# 16      69.0
# 17      18.0
# 18      55.0
# 19      35.0
# 20       NaN
# 21       NaN
# 22      20.0
# 23      54.0
# 24      25.0
# 25      25.0
# 26      22.0
# 27      31.0
# 28      15.0
# 29       NaN
# 30       NaN
# 31      54.0
# 32      40.0
# 33       NaN
# 34       NaN
# 35       NaN
# 36      18.0
# 37      35.0
# 38      37.0
# 39      69.0
# 40      13.0
# 41      34.0
# 42       NaN
# 43       NaN
# 44      40.0
# 45      50.0
# 46       NaN
# 47       NaN
# 48      46.0
# 49      13.0
# 50      48.0
# 51       NaN
# 52      32.0
# 53       NaN
# 54      17.0
# 55      28.0
# 56      17.0
# 57       NaN
# 58       NaN
# 59       NaN
# 60      55.0
# 61      48.0
# 62       NaN
# 63      55.0
# 64      20.0
# 65      65.0
# ...

# %%
df.age = df.fillna(df.age.median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1649 non-null   object
#  1   date                    1649 non-null   object
#  2   year                    1649 non-null   float64
#  3   type                    1649 non-null   object
#  4   country                 1649 non-null   object
#  5   area                    1649 non-null   object
#  6   location                1649 non-null   object
#  7   activity                1649 non-null   object
#  8   name                    1649 non-null   object
#  9   sex                     1649 non-null   object
#  10  age                     1421 non-null   float64
#  11  injury                  1649 non-null   object
#  12  fatal                   1649 non-null   object
#  13  time                    1647 non-null   object
# ...

# %%
def correct_data_cleaning(df):
    
    nota=0 # nota inicial
    
    if len(df.columns)==24:  # si el nº de columnas es 24...
        
        nota+=25
        
        
    if len(df)>=1500:   # si el nº de filas es igual o mayor a 1500...
        
        nota+=25
        
        
    if df.shape==df.dropna().shape:  # si el dataframe es igual al dropna...(no hay nulos)
        
        nota+=25
        
    
    
    # ahora check del tipo de dato.
    
    col_check=0  # variable estado: +1 si todo esta bien (al final debe coincidir con el nº de columnas)
    for c in df:   # para cada columna del dataframe....
        
        col_dtype=df[c].dtype       # type de la columna
        if col_dtype=='object':     # si el type de la columna es 'object', se pone string
            col_dtype=str
        elem_dtype=df[c].map(type)  # aplica el type a la serie, devuelve una serie con el type de cada elemento 
        elem_check=elem_dtype.apply(lambda x: x==col_dtype) # checkea si coincide, devuelve una serie de booleanos, True coincide
        if len(df)==sum(elem_check):  # si el nº de filas coincide con la suma del checkeo, todos los elemento tienen el mismo tipo
            
            col_check+=1
    
    if col_check==24:  # si coinciden es que todas las columnas tienen su propio tipo de dato correctamente puesto
        nota+=25
        
        
    return f'Tu nota es {nota}/100'

# %%
correct_data_cleaning(df)
# Out:
# 'Tu nota es 50/100'

# %%
df = df.dropna(axis = 0, subset=['time'])

# %%
correct_data_cleaning(df)
# Out:
# 'Tu nota es 50/100'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1647 entries, 0 to 1648
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1647 non-null   object
#  1   date                    1647 non-null   object
#  2   year                    1647 non-null   float64
#  3   type                    1647 non-null   object
#  4   country                 1647 non-null   object
#  5   area                    1647 non-null   object
#  6   location                1647 non-null   object
#  7   activity                1647 non-null   object
#  8   name                    1647 non-null   object
#  9   sex                     1647 non-null   object
#  10  age                     1419 non-null   float64
#  11  injury                  1647 non-null   object
#  12  fatal                   1647 non-null   object
#  13  time                    1647 non-null   object
# ...

# %%
df = df.dropna(axis = 0, subset=['species'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1644 entries, 0 to 1648
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1644 non-null   object
#  1   date                    1644 non-null   object
#  2   year                    1644 non-null   float64
#  3   type                    1644 non-null   object
#  4   country                 1644 non-null   object
#  5   area                    1644 non-null   object
#  6   location                1644 non-null   object
#  7   activity                1644 non-null   object
#  8   name                    1644 non-null   object
#  9   sex                     1644 non-null   object
#  10  age                     1416 non-null   float64
#  11  injury                  1644 non-null   object
#  12  fatal                   1644 non-null   object
#  13  time                    1644 non-null   object
# ...

# %%
correct_data_cleaning(df)
# Out:
# 'Tu nota es 75/100'

# %%
df.to_csv('kike_sharks_clean_v2', index = False)

# %%
df1 = pd.read_csv('kike_sharks_clean_v2', na_values=[' '])

# %%
correct_data_cleaning(df1)
# Out:
# 'Tu nota es 75/100'

# %%
df1.age = df1.age.fillna(df1.age.median())

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1644 entries, 0 to 1643
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1644 non-null   object
#  1   date                    1644 non-null   object
#  2   year                    1644 non-null   float64
#  3   type                    1644 non-null   object
#  4   country                 1644 non-null   object
#  5   area                    1644 non-null   object
#  6   location                1644 non-null   object
#  7   activity                1644 non-null   object
#  8   name                    1644 non-null   object
#  9   sex                     1644 non-null   object
#  10  age                     1644 non-null   float64
#  11  injury                  1644 non-null   object
#  12  fatal                   1644 non-null   object
#  13  time                    1644 non-null   object
# ...

# %%
correct_data_cleaning(df1)
# Out:
# 'Tu nota es 100/100'

# %%
df1.age = df1.age.astype('int64', errors='ignore')

# %%
correct_data_cleaning(df1)
# Out:
# 'Tu nota es 100/100'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1644 entries, 0 to 1643
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1644 non-null   object
#  1   date                    1644 non-null   object
#  2   year                    1644 non-null   float64
#  3   type                    1644 non-null   object
#  4   country                 1644 non-null   object
#  5   area                    1644 non-null   object
#  6   location                1644 non-null   object
#  7   activity                1644 non-null   object
#  8   name                    1644 non-null   object
#  9   sex                     1644 non-null   object
#  10  age                     1644 non-null   int64
#  11  injury                  1644 non-null   object
#  12  fatal                   1644 non-null   object
#  13  time                    1644 non-null   object
# ...

# %%
df1.age.unique()
# Out:
# array([57, 18, 15, 32, 21, 25, 30, 60, 33, 19, 10, 69, 55, 35, 20, 54, 22,
#        31, 40, 37, 13, 34, 50, 46, 48, 17, 28, 65, 73, 58, 36, 51, 61, 59,
#        42,  6, 23, 29, 39, 24, 12, 26, 11, 71, 43, 44, 14, 27, 62, 52, 38,
#        68, 16, 47, 63, 70,  9, 41, 53,  7, 66, 45, 74, 64,  8, 56, 49, 77,
#        84,  5], dtype=int32)

# %%
df1.age.value_counts()
# Out:
# 25    281
# 19     64
# 18     58
# 20     55
# 15     53
# 17     53
# 21     53
# 22     53
# 16     51
# 24     45
# 23     39
# 29     38
# 30     37
# 13     37
# 28     36
# 26     34
# 27     34
# 14     31
# 40     30
# 32     28
# 35     27
# 31     26
# 34     23
# 12     22
# 33     22
# 43     20
# 10     20
# 38     19
# 36     18
# 37     18
# 39     18
# 41     17
# 55     17
# 48     17
# 52     16
# 50     15
# 42     14
# 46     14
# 49     14
# 8      13
# 44     12
# 47     12
# 60     11
# 51     10
# 57     10
# 9      10
# 11      9
# 54      8
# 45      8
# 6       7
# 58      7
# 53      7
# 69      6
# 61      5
# 7       5
# 68      5
# 63      5
# 59      4
# 56      4
# 62      3
# 70      3
# 65      2
# 66      2
# 71      2
# 73      2
# 84      1
# 77      1
# 64      1
# 74      1
# 5       1
# Name: age, dtype: int64
